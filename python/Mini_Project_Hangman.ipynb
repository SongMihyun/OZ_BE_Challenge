# %% [markdown]
# ## Mini project [행맨 게임 제작]
#
# 안녕하세요.
# 수강생 여러분~! Chapter 1 ~ 6 까지의 수업은 잘 들으셨나요?
#
# 여러분의 모든 역량을 총 동원해 문제를 풀어주셨합니다.
#
#
#
# #### 과제 설명
#
# 이번 개발 주제는 '행맨' 게임이구요.
#
# 행맨 게임은 아주 유명한 단어 퀴즈 프로그램이예요
#
# 어떤 단어가 주어지면 그 단어의 길이만큼 빈 칸(밑줄) 이 주어지고
# 플레이어는 알파벳을 하나씩 얘기하면서 단어를 추측해요!
#
# 10번만에 맞히지 못하면 게임이 끝납니다. 🥲

# %% [markdown]
# #### 예시를 들어볼께요!!
#
# 만약 E 가 단어에 포함돼있다면, 해당하는 위치에 E 를 표시해줍니다
#
# _ _ _ _ E E
# 이렇게 되겠네요.
#
# 이번에는 A를 해볼께요
# A 는 포함되지 않으므로 기회가 줄어들고 지금까지 맞힌 내용 그대로 출력합니다.
#
# _ _ _ _ E E
# 변화가 없지요.
#
# 이번에는 C 를 해봅시다.
#
# 그럼
# C _ _ _ E E
#
# 다음에는 F 를
# C _ F F E E
#
# 마지막으로 O 를 해보면
# C O F F E E 로 게임은 성공으로 끝나게 됩니다.

# %% [markdown]
# ##본격적인 행맨 게임 규칙 설명
#
# - words 리스트에 추가된 단어들을 사용해주세요
#   - words = ["apple", "banana", "orange", "grape", "lemon"]
#
# - 단어의 길이에 맞게 밑줄을 출력해주세요
#   (예)banana의 경우 _ _ _ _ _ _
#
# - 사용자부터 1글자씩 입력을 받되,
#    - 단어에 입력값이 포함되면 "단어를 맞추셨군요. 더 힘내봐요"라고 출력해주세요"
#    - 단어에 입력값이 포함되어 있지 않다면 "틀렸습니다. 남은 시도 횟수 "란 메시지와 함꼐 남은 횟수를 출력해주세요
#
# - 매번 입력을 받을 때마다 현재까지 맞힌 글자들 표시(맞히면 글자는 밑줄 출력)
#     - 예) a 입력 시 : a _ _ _ _
#           p 입력 시 : a p p _ _
#           c 입력 시 : a p p _ _
#
# - 모든 단어를 맞췄을 경우 "축하합니다! 단어를 맞추셨습니다"와 시도 횟수를 출력해주세요
#
#
# 행맨은 정말 유명 게임으로 찾아볼 수 있는 자료들이 많습니다.
# 문제가 어려우신 경우 구글링 통해 문제를 해결해보세요.

# %%
# 기본 라이브러리라 파이썬 설치시 자동으로 설치됩니다!
# random 모듈은 랜덤한 숫자를 생성할 때 사용합니다.
import random

# 게임에 사용될 단어 목록
words = ["apple", "banana", "orange", "grape", "lemon"]

# 행맨 그림
hangman_pics = [
    """
         
     
     
     |
     |
    ---""",
    """
     |    
     |
     |
     |
     |
    ---""",
    """
     ------
     |    
     |
     |
     |
     |
    ---""",
    """
     ------
     |    |
     |
     |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |    |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\
     |   /
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\
     |   / \
     |
    ---""",
]


class HangmanGame:
    def __init__(self):
        self.words = ["apple", "banana", "orange", "grape", "lemon"]
        self.chan = 10
        self.chan_count = 0
        self.re_chan = self.chan-self.chan_count
        self.random_word=list(random.choice(self.words))
        self.random_word_blind=list(self.random_word)
        self.find_count = 0 
        
       
   
    def display(self):
        self.chan_count += 1    #사용찬스 카운팅
        self.re_chan -= 1   #남은기회 카운팅
        print('-------------------------------------')
        print(f'현재 단어 : {self.random_word_blind}')
        print(f'남은 기회 :  {self.re_chan}회') #남은 기회 출력
    
    def play(self):
        print(f'제시 단어 : {self.random_word}')    # 지울꺼예요~ // 확인용
        for i in range(len(self.random_word_blind)):
            self.random_word_blind[i] = "_"
        print(f'맞출 단어 : {self.random_word_blind}')  # 제시단어 출력용(단어수에 맞춰 '_'로 변경되어 출력) 
        
        while self.re_chan != 0 and self.find_count < len(self.random_word):   #남은 찬스가 0이 될때까지 돌아가는 조건문
            
            self.alpha = input("확인할 알파벳을 입력하세요. / 한글자만 입력하세요: ")
            
            try:
                int(self.alpha)
                print('숫자 입력은 안되요!')    
                continue        
            except ValueError:
            
                if  self.alpha in self.random_word_blind :
                    print("이미 사용한 단어 입니다!")
                    self.display()
                    continue    
        
                if len(self.alpha)==1 :    
                    for i in range(len(self.random_word)):
                        if self.alpha == self.random_word[i] :
                            self.random_word_blind[i] = self.alpha
                            self.find_count += 1  
                    
                                            
                else: 
                    print("한글자씩만 입력해주세요! 다시~")
                    continue                
                    
    
            self.display()            
        if self.re_chan == 0 :
            print("모든 기회가 소진되었습니다. 분발해 주세요~")
        else:
            print("와우!!!!!! 단어를 풀으셨군요!! 역시 !! 멋쪄요 +_+")

if __name__ == "__main__":
    game = HangmanGame()
    game.play()
# Out:
# 제시 단어 : ['o', 'r', 'a', 'n', 'g', 'e']
# 맞출 단어 : ['_', '_', '_', '_', '_', '_']
# -------------------------------------
# 현재 단어 : ['_', '_', 'a', '_', '_', '_']
# 남은 기회 :  9회
# 이미 사용한 단어 입니다!
# -------------------------------------
# 현재 단어 : ['_', '_', 'a', '_', '_', '_']
# 남은 기회 :  8회
# -------------------------------------
# 현재 단어 : ['_', '_', 'a', '_', '_', 'e']
# 남은 기회 :  7회
# 이미 사용한 단어 입니다!
# -------------------------------------
# 현재 단어 : ['_', '_', 'a', '_', '_', 'e']
# 남은 기회 :  6회
# 이미 사용한 단어 입니다!
# -------------------------------------
# 현재 단어 : ['_', '_', 'a', '_', '_', 'e']
# 남은 기회 :  5회
# 이미 사용한 단어 입니다!
# -------------------------------------
# 현재 단어 : ['_', '_', 'a', '_', '_', 'e']
# 남은 기회 :  4회
# 이미 사용한 단어 입니다!
# -------------------------------------
# 현재 단어 : ['_', '_', 'a', '_', '_', 'e']
# 남은 기회 :  3회
# -------------------------------------
# 현재 단어 : ['_', '_', 'a', '_', '_', 'e']
# 남은 기회 :  2회
# -------------------------------------
# 현재 단어 : ['_', '_', 'a', '_', '_', 'e']
# 남은 기회 :  1회
# -------------------------------------
# 현재 단어 : ['_', '_', 'a', '_', '_', 'e']
# 남은 기회 :  0회
# 모든 기회가 소진되었습니다. 분발해 주세요~
